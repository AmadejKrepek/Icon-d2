# %%
# File path
file_path = "./variable_folders/d2/d2_variables.txt"  # Replace with the actual path to your file

# Read the file and filter variables
selected_variables = []
with open(file_path, 'r') as file:
    lines = file.readlines()
    for line in lines:
        line = line.strip()  # Remove leading/trailing whitespace

# Print selected variables
for variable in selected_variables:
    print(variable)
