# %%
import numpy as np
import pandas as pd

# Define grid and temperature data (replace with your logic)
latitude_center, longitude_center = 46.1512, 14.9955
lat_min = latitude_center - 0.2
lat_max = latitude_center + 0.2
lon_min = longitude_center - 0.2
lon_max = longitude_center + 0.2
lat_values = np.linspace(lat_min, lat_max, int((lat_max - lat_min) / 0.018))
lon_values = np.linspace(lon_min, lon_max, int((lon_max - lon_min) / 0.018))
temperature_2m = np.random.rand(len(lat_values), len(lon_values)) # Random temperatures for this example

# Create DataFrame and save to CSV
df = pd.DataFrame(
    [(lat, lon, temperature_2m[i, j]) for i, lat in enumerate(lat_values) for j, lon in enumerate(lon_values)],
    columns=['Latitude', 'Longitude', 'Temperature']
)
df.to_csv('temperature_data.csv', index=False)
