# %%
import psycopg2
import uuid
from dotenv import load_dotenv
import os

# Load environment variables from .env
load_dotenv()

def seed_tables():
    try:
        # Access the environment variables
        DB_USERNAME = os.getenv("DB_USERNAME")
        DB_PASSWORD = os.getenv("DB_PASSWORD")
        DB_HOST = os.getenv("DB_HOST")
        DB_PORT = os.getenv("DB_PORT")
        DB_NAME = os.getenv("DB_NAME")

        # Establish a connection to the PostgreSQL database
        conn = psycopg2.connect(
            host=DB_HOST,
            port=DB_PORT,
            database=DB_NAME,
            user=DB_USERNAME,
            password=DB_PASSWORD
        )

        # Create a cursor object
        cursor = conn.cursor()

        # Seed the provider table
        cursor.execute("""
            INSERT INTO provider (id, name) VALUES
            (uuid_generate_v4(), 'DWD'),
            (uuid_generate_v4(), 'ARSO'),
            (uuid_generate_v4(), 'ECMWF'),
            (uuid_generate_v4(), 'GFS')
        """)

        # Seed the model table
        cursor.execute(f"""
            INSERT INTO model (id, name, area, country, region, max_bbox, selected_bbox, provider_id) VALUES
            (uuid_generate_v4(), 'IconD2', 'Central Europe', 'Germany', null, null, null, (SELECT id FROM provider WHERE name = 'DWD')),
            (uuid_generate_v4(), 'IconD2', 'Central Europe', 'Switzerland', null, null, null, (SELECT id FROM provider WHERE name = 'DWD')),
            (uuid_generate_v4(), 'IconD2', 'Central Europe', 'Liechtenstein', null, null, null, (SELECT id FROM provider WHERE name = 'DWD')),
            (uuid_generate_v4(), 'IconD2', 'Central Europe', 'Austria', null, null, null, (SELECT id FROM provider WHERE name = 'DWD')),
            (uuid_generate_v4(), 'IconD2', 'Central Europe', 'Belgium', null, null, null, (SELECT id FROM provider WHERE name = 'DWD')),
            (uuid_generate_v4(), 'IconD2', 'Central Europe', 'Bosnia', null, null, null, (SELECT id FROM provider WHERE name = 'DWD')),
            (uuid_generate_v4(), 'IconD2', 'Central Europe', 'Croatia', null, null, null, (SELECT id FROM provider WHERE name = 'DWD')),
            (uuid_generate_v4(), 'IconD2', 'Central Europe', 'Czech Republic', null, null, null, (SELECT id FROM provider WHERE name = 'DWD')),
            (uuid_generate_v4(), 'IconD2', 'Central Europe', 'Denmark', null, null, null, (SELECT id FROM provider WHERE name = 'DWD')),
            (uuid_generate_v4(), 'IconD2', 'Central Europe', 'England', null, null, null, (SELECT id FROM provider WHERE name = 'DWD')),
            (uuid_generate_v4(), 'IconD2', 'Central Europe', 'France', null, null, null, (SELECT id FROM provider WHERE name = 'DWD')),
            (uuid_generate_v4(), 'IconD2', 'Central Europe', 'Hungary', null, null, null, (SELECT id FROM provider WHERE name = 'DWD')),
            (uuid_generate_v4(), 'IconD2', 'Central Europe', 'Italy', null, null, null, (SELECT id FROM provider WHERE name = 'DWD')),
            (uuid_generate_v4(), 'IconD2', 'Central Europe', 'Luxembourg', null, null, null, (SELECT id FROM provider WHERE name = 'DWD')),
            (uuid_generate_v4(), 'IconD2', 'Central Europe', 'Monaco', null, null, null, (SELECT id FROM provider WHERE name = 'DWD')),
            (uuid_generate_v4(), 'IconD2', 'Central Europe', 'Netherlands', null, null, null, (SELECT id FROM provider WHERE name = 'DWD')),
            (uuid_generate_v4(), 'IconD2', 'Central Europe', 'Poland', null, null, null, (SELECT id FROM provider WHERE name = 'DWD')),
            (uuid_generate_v4(), 'IconD2', 'Central Europe', 'San Marino', null, null, null, (SELECT id FROM provider WHERE name = 'DWD')),
            (uuid_generate_v4(), 'IconD2', 'Central Europe', 'Slovenia', null, null, null, (SELECT id FROM provider WHERE name = 'DWD')),
            (uuid_generate_v4(), 'IconD2', 'Central Europe', 'Sweden', null, null, null, (SELECT id FROM provider WHERE name = 'DWD')),
            (uuid_generate_v4(), 'IconD2', 'Central Europe', 'Slovenia', 'Slovenske gorice', null, null, (SELECT id FROM provider WHERE name = 'DWD')),
            (uuid_generate_v4(), 'IconD2', 'Central Europe', 'Slovenia', 'Severovzhod', null, null, (SELECT id FROM provider WHERE name = 'DWD')),
            (uuid_generate_v4(), 'IconD2', 'Central Europe', 'Slovenia', 'Severozahod', null, null,(SELECT id FROM provider WHERE name = 'DWD')),
            (uuid_generate_v4(), 'IconD2', 'Central Europe', 'Slovenia', 'Osrednja', null, null, (SELECT id FROM provider WHERE name = 'DWD')),
            (uuid_generate_v4(), 'IconD2', 'Central Europe', 'Slovenia', 'Jugozahod', null, null, (SELECT id FROM provider WHERE name = 'DWD')),
            (uuid_generate_v4(), 'IconD2', 'Central Europe', 'Slovenia', 'Jugovzhod', null, null, (SELECT id FROM provider WHERE name = 'DWD')),
            (uuid_generate_v4(), 'IconD2', 'Central Europe', null, null, null, null, (SELECT id FROM provider WHERE name = 'DWD'))
        """)

        # Seed the model table
        cursor.execute(f"""
            INSERT INTO model (id, name, area, country, region, max_bbox, selected_bbox, provider_id) VALUES
            (uuid_generate_v4(), 'IconEU', 'Europe', null, null, null, null, (SELECT id FROM provider WHERE name = 'DWD')),
            (uuid_generate_v4(), 'IconEU', 'Central Europe', null, null, null, null, (SELECT id FROM provider WHERE name = 'DWD')),
            (uuid_generate_v4(), 'IconEU', 'Southern Europe', null, null, null, null, (SELECT id FROM provider WHERE name = 'DWD')),
            (uuid_generate_v4(), 'IconEU', 'Southeastern Europe', null, null, null, null, (SELECT id FROM provider WHERE name = 'DWD')),
            (uuid_generate_v4(), 'IconEU', 'Eastern Europe', null, null, null, null, (SELECT id FROM provider WHERE name = 'DWD')),
            (uuid_generate_v4(), 'IconEU', 'Scandinavia', null, null, null, null, (SELECT id FROM provider WHERE name = 'DWD')),
            (uuid_generate_v4(), 'IconEU', 'Central Europe', 'Slovenia', null, null, null, (SELECT id FROM provider WHERE name = 'DWD'))
        """)

        # Seed the model table
        cursor.execute(f"""
            INSERT INTO model (id, name, area, country, region, max_bbox, selected_bbox, provider_id) VALUES
            (uuid_generate_v4(), 'Icon', 'World', null, null, null, null, (SELECT id FROM provider WHERE name = 'DWD'))
        """)

        # Seed the model table
        cursor.execute(f"""
            INSERT INTO model (id, name, area, country, region, max_bbox, selected_bbox, provider_id) VALUES
            (uuid_generate_v4(), 'ECMWF', 'Europe', null, null, null, null, (SELECT id FROM provider WHERE name = 'ECMWF')),
            (uuid_generate_v4(), 'ECMWF', 'Central Europe', null, null, null, null, (SELECT id FROM provider WHERE name = 'ECMWF')),
            (uuid_generate_v4(), 'ECMWF', 'Central Europe', 'Slovenia', null, null, null, (SELECT id FROM provider WHERE name = 'ECMWF'))
        """)

        # Seed the model table
        cursor.execute(f"""
            INSERT INTO model (id, name, area, country, region, max_bbox, selected_bbox, provider_id) VALUES
            (uuid_generate_v4(), 'Aladin', 'Central Europe', 'Slovenia', null, null, null, (SELECT id FROM provider WHERE name = 'ARSO')),
            (uuid_generate_v4(), 'Aladin', 'Central Europe','Slovenia', 'Slovenske gorice', null, null, (SELECT id FROM provider WHERE name = 'ARSO')),
            (uuid_generate_v4(), 'Aladin', 'Central Europe', null, null, null, null, (SELECT id FROM provider WHERE name = 'ARSO'))
        """)

        # Commit the changes
        conn.commit()

        # Close the cursor and the connection
        cursor.close()
        conn.close()

        print("Tables seeded successfully.")

    except Exception as e:
        print(f"Error: {e}")

if __name__ == "__main__":
    seed_tables()
# Out:
# Tables seeded successfully.
