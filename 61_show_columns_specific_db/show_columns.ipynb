# %%
import psycopg2
from dotenv import load_dotenv
import os

# Load environment variables from .env
load_dotenv()

def show_table_columns_structure(table_name):
    try:
        # Access the environment variables
        DB_USERNAME = os.getenv("DB_USERNAME")
        DB_PASSWORD = os.getenv("DB_PASSWORD")
        DB_HOST = os.getenv("DB_HOST")
        DB_PORT = os.getenv("DB_PORT")
        DB_NAME = os.getenv("DB_NAME")

        # Establish a connection to the PostgreSQL database
        conn = psycopg2.connect(
            host=DB_HOST,
            port=DB_PORT,
            database=DB_NAME,
            user=DB_USERNAME,
            password=DB_PASSWORD
        )

        # Create a cursor object
        cursor = conn.cursor()

        # Query to retrieve column names and data types
        cursor.execute(f"SELECT column_name, data_type FROM information_schema.columns WHERE table_name = '{table_name}';")

        # Fetch all column information
        column_info = cursor.fetchall()

        # Close the cursor and the connection
        cursor.close()
        conn.close()

        # Display column names and data types
        print(f"Columns and Data Types for Table '{table_name}':")
        for col_name, data_type in column_info:
            print(f"Column Name: {col_name}, Data Type: {data_type}")

    except Exception as e:
        print(f"Error: {e}")

if __name__ == "__main__":
    # Specify the table name you want to show column structure for
    table_name_to_show_structure = "total_precipitation"

    show_table_columns_structure(table_name_to_show_structure)
# Out:
# Columns and Data Types for Table 'total_precipitation':
# Column Name: id, Data Type: integer
# Column Name: provider_id, Data Type: character varying
# Column Name: model_id, Data Type: character varying
# Column Name: model_run, Data Type: integer
# Column Name: Total Precipitation, Data Type: ARRAY
# Column Name: start_date, Data Type: timestamp without time zone
# Column Name: end_date, Data Type: timestamp without time zone
# Column Name: interval, Data Type: interval
