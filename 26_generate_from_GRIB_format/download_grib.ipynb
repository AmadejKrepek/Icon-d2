# %%
import requests
import os

# URL for the directory containing GRIB files
base_url = "https://opendata.dwd.de/weather/nwp/icon-d2/grib/15/t_2m/"

# Directory to save downloaded files
output_directory = "downloaded_grib_files"

# Create the output directory if it doesn't exist
os.makedirs(output_directory, exist_ok=True)

# Loop through the dynamic values from 000 to 047
for dynamic_value in range(48):
    filename = f"icon-d2_germany_icosahedral_single-level_2023081815_{dynamic_value:03d}_2d_t_2m.grib2.bz2"
    url = f"{base_url}/{filename}"
    output_path = os.path.join(output_directory, filename)

    response = requests.get(url)
    with open(output_path, "wb") as f:
        f.write(response.content)

    print(f"Downloaded: {filename}")

print("Download complete.")
# Out:
# Downloaded: icon-d2_germany_icosahedral_single-level_2023081815_000_2d_t_2m.grib2.bz2
# Downloaded: icon-d2_germany_icosahedral_single-level_2023081815_001_2d_t_2m.grib2.bz2
# Downloaded: icon-d2_germany_icosahedral_single-level_2023081815_002_2d_t_2m.grib2.bz2
# Downloaded: icon-d2_germany_icosahedral_single-level_2023081815_003_2d_t_2m.grib2.bz2
# Downloaded: icon-d2_germany_icosahedral_single-level_2023081815_004_2d_t_2m.grib2.bz2
# Downloaded: icon-d2_germany_icosahedral_single-level_2023081815_005_2d_t_2m.grib2.bz2
# Downloaded: icon-d2_germany_icosahedral_single-level_2023081815_006_2d_t_2m.grib2.bz2
# Downloaded: icon-d2_germany_icosahedral_single-level_2023081815_007_2d_t_2m.grib2.bz2
# Downloaded: icon-d2_germany_icosahedral_single-level_2023081815_008_2d_t_2m.grib2.bz2
# Downloaded: icon-d2_germany_icosahedral_single-level_2023081815_009_2d_t_2m.grib2.bz2
# Downloaded: icon-d2_germany_icosahedral_single-level_2023081815_010_2d_t_2m.grib2.bz2
# Downloaded: icon-d2_germany_icosahedral_single-level_2023081815_011_2d_t_2m.grib2.bz2
# Downloaded: icon-d2_germany_icosahedral_single-level_2023081815_012_2d_t_2m.grib2.bz2
# Downloaded: icon-d2_germany_icosahedral_single-level_2023081815_013_2d_t_2m.grib2.bz2
# Downloaded: icon-d2_germany_icosahedral_single-level_2023081815_014_2d_t_2m.grib2.bz2
# Downloaded: icon-d2_germany_icosahedral_single-level_2023081815_015_2d_t_2m.grib2.bz2
# Downloaded: icon-d2_germany_icosahedral_single-level_2023081815_016_2d_t_2m.grib2.bz2
# Downloaded: icon-d2_germany_icosahedral_single-level_2023081815_017_2d_t_2m.grib2.bz2
# Downloaded: icon-d2_germany_icosahedral_single-level_2023081815_018_2d_t_2m.grib2.bz2
# Downloaded: icon-d2_germany_icosahedral_single-level_2023081815_019_2d_t_2m.grib2.bz2
# Downloaded: icon-d2_germany_icosahedral_single-level_2023081815_020_2d_t_2m.grib2.bz2
# Downloaded: icon-d2_germany_icosahedral_single-level_2023081815_021_2d_t_2m.grib2.bz2
# Downloaded: icon-d2_germany_icosahedral_single-level_2023081815_022_2d_t_2m.grib2.bz2
# Downloaded: icon-d2_germany_icosahedral_single-level_2023081815_023_2d_t_2m.grib2.bz2
# Downloaded: icon-d2_germany_icosahedral_single-level_2023081815_024_2d_t_2m.grib2.bz2
# Downloaded: icon-d2_germany_icosahedral_single-level_2023081815_025_2d_t_2m.grib2.bz2
# Downloaded: icon-d2_germany_icosahedral_single-level_2023081815_026_2d_t_2m.grib2.bz2
# Downloaded: icon-d2_germany_icosahedral_single-level_2023081815_027_2d_t_2m.grib2.bz2
# Downloaded: icon-d2_germany_icosahedral_single-level_2023081815_028_2d_t_2m.grib2.bz2
# Downloaded: icon-d2_germany_icosahedral_single-level_2023081815_029_2d_t_2m.grib2.bz2
# Downloaded: icon-d2_germany_icosahedral_single-level_2023081815_030_2d_t_2m.grib2.bz2
# Downloaded: icon-d2_germany_icosahedral_single-level_2023081815_031_2d_t_2m.grib2.bz2
# Downloaded: icon-d2_germany_icosahedral_single-level_2023081815_032_2d_t_2m.grib2.bz2
# Downloaded: icon-d2_germany_icosahedral_single-level_2023081815_033_2d_t_2m.grib2.bz2
# Downloaded: icon-d2_germany_icosahedral_single-level_2023081815_034_2d_t_2m.grib2.bz2
# Downloaded: icon-d2_germany_icosahedral_single-level_2023081815_035_2d_t_2m.grib2.bz2
# Downloaded: icon-d2_germany_icosahedral_single-level_2023081815_036_2d_t_2m.grib2.bz2
# Downloaded: icon-d2_germany_icosahedral_single-level_2023081815_037_2d_t_2m.grib2.bz2
# Downloaded: icon-d2_germany_icosahedral_single-level_2023081815_038_2d_t_2m.grib2.bz2
# Downloaded: icon-d2_germany_icosahedral_single-level_2023081815_039_2d_t_2m.grib2.bz2
# Downloaded: icon-d2_germany_icosahedral_single-level_2023081815_040_2d_t_2m.grib2.bz2
# Downloaded: icon-d2_germany_icosahedral_single-level_2023081815_041_2d_t_2m.grib2.bz2
# Downloaded: icon-d2_germany_icosahedral_single-level_2023081815_042_2d_t_2m.grib2.bz2
# Downloaded: icon-d2_germany_icosahedral_single-level_2023081815_043_2d_t_2m.grib2.bz2
# Downloaded: icon-d2_germany_icosahedral_single-level_2023081815_044_2d_t_2m.grib2.bz2
# Downloaded: icon-d2_germany_icosahedral_single-level_2023081815_045_2d_t_2m.grib2.bz2
# Downloaded: icon-d2_germany_icosahedral_single-level_2023081815_046_2d_t_2m.grib2.bz2
# Downloaded: icon-d2_germany_icosahedral_single-level_2023081815_047_2d_t_2m.grib2.bz2
# Download complete.
