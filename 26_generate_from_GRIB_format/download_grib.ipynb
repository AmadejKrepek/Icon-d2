# %%
import requests
import os

# URL for the directory containing GRIB files
base_url = "https://opendata.dwd.de/weather/nwp/icon-d2/grib/15/t_2m/"

# Directory to save downloaded files
output_directory = "downloaded_grib_files"

# Create the output directory if it doesn't exist
os.makedirs(output_directory, exist_ok=True)
# Loop through the dynamic values from 000 to 047
for dynamic_value in range(48):
    filename = f"icon-d2_germany_regular-lat-lon_single-level_2023082015_{dynamic_value:03d}_2d_t_2m.grib2.bz2"
    url = f"{base_url}/{filename}"
    output_path = os.path.join(output_directory, filename)

    response = requests.get(url)
    with open(output_path, "wb") as f:
        f.write(response.content)

    print(f"Downloaded: {filename}")

print("Download complete.")
# Out:
# Downloaded: icon-d2_germany_regular-lat-lon_single-level_2023082015_000_2d_t_2m.grib2.bz2
# Downloaded: icon-d2_germany_regular-lat-lon_single-level_2023082015_001_2d_t_2m.grib2.bz2
# Downloaded: icon-d2_germany_regular-lat-lon_single-level_2023082015_002_2d_t_2m.grib2.bz2
# Downloaded: icon-d2_germany_regular-lat-lon_single-level_2023082015_003_2d_t_2m.grib2.bz2
# Downloaded: icon-d2_germany_regular-lat-lon_single-level_2023082015_004_2d_t_2m.grib2.bz2
# Downloaded: icon-d2_germany_regular-lat-lon_single-level_2023082015_005_2d_t_2m.grib2.bz2
# Downloaded: icon-d2_germany_regular-lat-lon_single-level_2023082015_006_2d_t_2m.grib2.bz2
# Downloaded: icon-d2_germany_regular-lat-lon_single-level_2023082015_007_2d_t_2m.grib2.bz2
# Downloaded: icon-d2_germany_regular-lat-lon_single-level_2023082015_008_2d_t_2m.grib2.bz2
# Downloaded: icon-d2_germany_regular-lat-lon_single-level_2023082015_009_2d_t_2m.grib2.bz2
# Downloaded: icon-d2_germany_regular-lat-lon_single-level_2023082015_010_2d_t_2m.grib2.bz2
# Downloaded: icon-d2_germany_regular-lat-lon_single-level_2023082015_011_2d_t_2m.grib2.bz2
# Downloaded: icon-d2_germany_regular-lat-lon_single-level_2023082015_012_2d_t_2m.grib2.bz2
# Downloaded: icon-d2_germany_regular-lat-lon_single-level_2023082015_013_2d_t_2m.grib2.bz2
# Downloaded: icon-d2_germany_regular-lat-lon_single-level_2023082015_014_2d_t_2m.grib2.bz2
# Downloaded: icon-d2_germany_regular-lat-lon_single-level_2023082015_015_2d_t_2m.grib2.bz2
# Downloaded: icon-d2_germany_regular-lat-lon_single-level_2023082015_016_2d_t_2m.grib2.bz2
# Downloaded: icon-d2_germany_regular-lat-lon_single-level_2023082015_017_2d_t_2m.grib2.bz2
# Downloaded: icon-d2_germany_regular-lat-lon_single-level_2023082015_018_2d_t_2m.grib2.bz2
# Downloaded: icon-d2_germany_regular-lat-lon_single-level_2023082015_019_2d_t_2m.grib2.bz2
# Downloaded: icon-d2_germany_regular-lat-lon_single-level_2023082015_020_2d_t_2m.grib2.bz2
# Downloaded: icon-d2_germany_regular-lat-lon_single-level_2023082015_021_2d_t_2m.grib2.bz2
# Downloaded: icon-d2_germany_regular-lat-lon_single-level_2023082015_022_2d_t_2m.grib2.bz2
# Downloaded: icon-d2_germany_regular-lat-lon_single-level_2023082015_023_2d_t_2m.grib2.bz2
# Downloaded: icon-d2_germany_regular-lat-lon_single-level_2023082015_024_2d_t_2m.grib2.bz2
# Downloaded: icon-d2_germany_regular-lat-lon_single-level_2023082015_025_2d_t_2m.grib2.bz2
# Downloaded: icon-d2_germany_regular-lat-lon_single-level_2023082015_026_2d_t_2m.grib2.bz2
# Downloaded: icon-d2_germany_regular-lat-lon_single-level_2023082015_027_2d_t_2m.grib2.bz2
# Downloaded: icon-d2_germany_regular-lat-lon_single-level_2023082015_028_2d_t_2m.grib2.bz2
# Downloaded: icon-d2_germany_regular-lat-lon_single-level_2023082015_029_2d_t_2m.grib2.bz2
# Downloaded: icon-d2_germany_regular-lat-lon_single-level_2023082015_030_2d_t_2m.grib2.bz2
# Downloaded: icon-d2_germany_regular-lat-lon_single-level_2023082015_031_2d_t_2m.grib2.bz2
# Downloaded: icon-d2_germany_regular-lat-lon_single-level_2023082015_032_2d_t_2m.grib2.bz2
# Downloaded: icon-d2_germany_regular-lat-lon_single-level_2023082015_033_2d_t_2m.grib2.bz2
# Downloaded: icon-d2_germany_regular-lat-lon_single-level_2023082015_034_2d_t_2m.grib2.bz2
# Downloaded: icon-d2_germany_regular-lat-lon_single-level_2023082015_035_2d_t_2m.grib2.bz2
# Downloaded: icon-d2_germany_regular-lat-lon_single-level_2023082015_036_2d_t_2m.grib2.bz2
# Downloaded: icon-d2_germany_regular-lat-lon_single-level_2023082015_037_2d_t_2m.grib2.bz2
# Downloaded: icon-d2_germany_regular-lat-lon_single-level_2023082015_038_2d_t_2m.grib2.bz2
# Downloaded: icon-d2_germany_regular-lat-lon_single-level_2023082015_039_2d_t_2m.grib2.bz2
# Downloaded: icon-d2_germany_regular-lat-lon_single-level_2023082015_040_2d_t_2m.grib2.bz2
# Downloaded: icon-d2_germany_regular-lat-lon_single-level_2023082015_041_2d_t_2m.grib2.bz2
# Downloaded: icon-d2_germany_regular-lat-lon_single-level_2023082015_042_2d_t_2m.grib2.bz2
# Downloaded: icon-d2_germany_regular-lat-lon_single-level_2023082015_043_2d_t_2m.grib2.bz2
# Downloaded: icon-d2_germany_regular-lat-lon_single-level_2023082015_044_2d_t_2m.grib2.bz2
# Downloaded: icon-d2_germany_regular-lat-lon_single-level_2023082015_045_2d_t_2m.grib2.bz2
# Downloaded: icon-d2_germany_regular-lat-lon_single-level_2023082015_046_2d_t_2m.grib2.bz2
# Downloaded: icon-d2_germany_regular-lat-lon_single-level_2023082015_047_2d_t_2m.grib2.bz2
# Download complete.
