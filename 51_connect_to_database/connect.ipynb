# %%
import psycopg2

with psycopg2.connect(CONNECTION) as conn:
    cursor = conn.cursor()
    # use the cursor to interact with your database
    # cursor.execute("SELECT * FROM table")
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# c:\Users\admin\Documents\Weather\Projects\Icon d2\51_connect_to_database\connect.ipynb Cell 1 line 5
#       <a href='vscode-notebook-cell:/c%3A/Users/admin/Documents/Weather/Projects/Icon%20d2/51_connect_to_database/connect.ipynb#W0sZmlsZQ%3D%3D?line=0'>1</a> import psycopg2
#       <a href='vscode-notebook-cell:/c%3A/Users/admin/Documents/Weather/Projects/Icon%20d2/51_connect_to_database/connect.ipynb#W0sZmlsZQ%3D%3D?line=2'>3</a> CONNECTION = "postgres://postgres:cuftek71CrazyMan42#@192.168.0.100:5432/test"
# ----> <a href='vscode-notebook-cell:/c%3A/Users/admin/Documents/Weather/Projects/Icon%20d2/51_connect_to_database/connect.ipynb#W0sZmlsZQ%3D%3D?line=4'>5</a> with psycopg2.connect(CONNECTION) as conn:
#       <a href='vscode-notebook-cell:/c%3A/Users/admin/Documents/Weather/Projects/Icon%20d2/51_connect_to_database/connect.ipynb#W0sZmlsZQ%3D%3D?line=5'>6</a>     cursor = conn.cursor()
#
# File c:\Users\admin\miniconda3\envs\tf\lib\site-packages\psycopg2\__init__.py:122, in connect(dsn, connection_factory, cursor_factory, **kwargs)
#     119     kwasync['async_'] = kwargs.pop('async_')
#     121 dsn = _ext.make_dsn(dsn, **kwargs)
# --> 122 conn = _connect(dsn, connection_factory=connection_factory, **kwasync)
#     123 if cursor_factory is not None:
#     124     conn.cursor_factory = cursor_factory
#
# OperationalError: connection to server at "192.168.0.100", port 5432 failed: Connection timed out (0x0000274C/10060)
# 	Is the server running on that host and accepting TCP/IP connections?
