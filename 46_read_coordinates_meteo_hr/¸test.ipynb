# %%
import numpy as np
import imageio

# Load the radar image
image_path = '../45_hr_kompozit_download/data/2023/08/30/meteo_hr_radar_stat_kompozit_2023_08_30_10_18_26.jpg'
radar_image = imageio.imread(image_path)

# Define the bounding box coordinates for Slovenia and neighboring countries
min_lat = 45.4
max_lat = 47.1
min_lon = 13.4
max_lon = 16.6

# Get the dimensions of the radar image
height, width = radar_image.shape[:2]

# Calculate the latitude and longitude step sizes
lat_step = (max_lat - min_lat) / height
lon_step = (max_lon - min_lon) / width

# Initialize empty lists to store data
latitudes = []
longitudes = []
values = []

# Loop through each pixel in the radar image and extract data
for y in range(height):
    for x in range(width):
        # Calculate latitude and longitude for the current pixel
        lat = max_lat - y * lat_step
        lon = min_lon + x * lon_step
        
        # Get the value at the current pixel
        value = radar_image[y, x]
        
        # Append data to lists
        latitudes.append(lat)
        longitudes.append(lon)
        values.append(value)

# Now you have the latitudes, longitudes, and values extracted from the radar image
# You can use these lists for further processing or visualization

# Example: Print the first few entries
for i in range(10):
    print(f"Latitude: {latitudes[i]}, Longitude: {longitudes[i]}, Value: {values[i]}")
# Out:
# C:\Users\admin\AppData\Local\Temp\ipykernel_15376\1502204200.py:6: DeprecationWarning: Starting with ImageIO v3 the behavior of this function will switch to that of iio.v3.imread. To keep the current behavior (and make this warning disappear) use `import imageio.v2 as imageio` or call `imageio.v2.imread` directly.
#   radar_image = imageio.imread(image_path)
# Latitude: 47.1, Longitude: 13.4, Value: [0 0 0]
# Latitude: 47.1, Longitude: 13.404444444444445, Value: [0 0 0]
# Latitude: 47.1, Longitude: 13.408888888888889, Value: [0 0 0]
# Latitude: 47.1, Longitude: 13.413333333333334, Value: [0 0 0]
# Latitude: 47.1, Longitude: 13.417777777777777, Value: [0 0 0]
# Latitude: 47.1, Longitude: 13.422222222222222, Value: [0 0 0]
# Latitude: 47.1, Longitude: 13.426666666666668, Value: [0 0 0]
# Latitude: 47.1, Longitude: 13.431111111111111, Value: [0 0 0]
# Latitude: 47.1, Longitude: 13.435555555555556, Value: [0 0 0]
# Latitude: 47.1, Longitude: 13.44, Value: [0 0 0]
