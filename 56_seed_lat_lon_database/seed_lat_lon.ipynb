# %%
import psycopg2
import csv
from dotenv import load_dotenv
import os

# Load environment variables from .env
load_dotenv()

def seed_lat_lon_schema():
    try:
        # Access the environment variables
        DB_USERNAME = os.getenv("DB_USERNAME")
        DB_PASSWORD = os.getenv("DB_PASSWORD")
        DB_HOST = os.getenv("DB_HOST")
        DB_PORT = os.getenv("DB_PORT")
        DB_NAME = os.getenv("DB_NAME")

        # Database connection
        conn = psycopg2.connect(
            host=DB_HOST,
            port=DB_PORT,
            database=DB_NAME,
            user=DB_USERNAME,
            password=DB_PASSWORD
        )

        cursor = conn.cursor()

        # Path to CSV file containing latitude and longitude data
        csv_file_dwd = "./icon_d2_lat_lon.csv"
        csv_file_arso = "./aladin_lat_lon.csv"

        # Insert data into lat_lon_schema for DWD
        with open(csv_file_dwd, "r") as file_dwd:
            csv_reader_dwd = csv.reader(file_dwd)
            next(csv_reader_dwd)  # Skip the header row if present
            for row in csv_reader_dwd:
                latitude = float(row[0])
                longitude = float(row[1])
                cursor.execute("INSERT INTO lat_lon_schema (provider_id, latitude, longitude) VALUES (%s, %s, %s)", ("6be8cea2-f29b-4198-aa68-10c57845ad25", latitude, longitude))

        # Insert data into lat_lon_schema for ARSO
        with open(csv_file_arso, "r") as file_arso:
            csv_reader_arso = csv.reader(file_arso)
            next(csv_reader_arso)  # Skip the header row if present
            for row in csv_reader_arso:
                latitude = float(row[0])
                longitude = float(row[1])
                cursor.execute("INSERT INTO lat_lon_schema (provider_id, latitude, longitude) VALUES (%s, %s, %s)", ("66b97430-1782-4793-906d-f77b4303373b", latitude, longitude))

        # Commit the changes
        conn.commit()

        # Close the cursor and the connection
        cursor.close()
        conn.close()

        print("Latitude and Longitude data seeded successfully.")

    except Exception as e:
        print(f"Error: {e}")

if __name__ == "__main__":
    seed_lat_lon_schema()
# Out:
# Latitude and Longitude data seeded successfully.
