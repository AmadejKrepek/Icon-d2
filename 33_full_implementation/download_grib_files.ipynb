# %%
import requests
import os

# URL for the directory containing GRIB files
base_url = "https://opendata.dwd.de/weather/nwp/icon-d2/grib/15/t_2m/"

# Directory to save downloaded files
output_directory = "downloaded_grib_files"

# Create the output directory if it doesn't exist
os.makedirs(output_directory, exist_ok=True)
# Loop through the dynamic values from 000 to 047
for dynamic_value in range(48):
    filename = f"icon-d2_germany_regular-lat-lon_single-level_2023082115_{dynamic_value:03d}_2d_t_2m.grib2.bz2"
    url = f"{base_url}/{filename}"
    output_path = os.path.join(output_directory, filename)

    response = requests.get(url)
    with open(output_path, "wb") as f:
        f.write(response.content)

    print(f"Downloaded: {filename}")

print("Download complete.")
# Out:
# Downloaded: icon-d2_germany_regular-lat-lon_single-level_2023082115_000_2d_t_2m.grib2.bz2
# Downloaded: icon-d2_germany_regular-lat-lon_single-level_2023082115_001_2d_t_2m.grib2.bz2
# Downloaded: icon-d2_germany_regular-lat-lon_single-level_2023082115_002_2d_t_2m.grib2.bz2
# Downloaded: icon-d2_germany_regular-lat-lon_single-level_2023082115_003_2d_t_2m.grib2.bz2
# Downloaded: icon-d2_germany_regular-lat-lon_single-level_2023082115_004_2d_t_2m.grib2.bz2
# Downloaded: icon-d2_germany_regular-lat-lon_single-level_2023082115_005_2d_t_2m.grib2.bz2
# Downloaded: icon-d2_germany_regular-lat-lon_single-level_2023082115_006_2d_t_2m.grib2.bz2
# Downloaded: icon-d2_germany_regular-lat-lon_single-level_2023082115_007_2d_t_2m.grib2.bz2
# Downloaded: icon-d2_germany_regular-lat-lon_single-level_2023082115_008_2d_t_2m.grib2.bz2
# Downloaded: icon-d2_germany_regular-lat-lon_single-level_2023082115_009_2d_t_2m.grib2.bz2
# Downloaded: icon-d2_germany_regular-lat-lon_single-level_2023082115_010_2d_t_2m.grib2.bz2
# Downloaded: icon-d2_germany_regular-lat-lon_single-level_2023082115_011_2d_t_2m.grib2.bz2
# Downloaded: icon-d2_germany_regular-lat-lon_single-level_2023082115_012_2d_t_2m.grib2.bz2
# Downloaded: icon-d2_germany_regular-lat-lon_single-level_2023082115_013_2d_t_2m.grib2.bz2
# Downloaded: icon-d2_germany_regular-lat-lon_single-level_2023082115_014_2d_t_2m.grib2.bz2
# Downloaded: icon-d2_germany_regular-lat-lon_single-level_2023082115_015_2d_t_2m.grib2.bz2
# Downloaded: icon-d2_germany_regular-lat-lon_single-level_2023082115_016_2d_t_2m.grib2.bz2
# Downloaded: icon-d2_germany_regular-lat-lon_single-level_2023082115_017_2d_t_2m.grib2.bz2
# Downloaded: icon-d2_germany_regular-lat-lon_single-level_2023082115_018_2d_t_2m.grib2.bz2
# Downloaded: icon-d2_germany_regular-lat-lon_single-level_2023082115_019_2d_t_2m.grib2.bz2
# Downloaded: icon-d2_germany_regular-lat-lon_single-level_2023082115_020_2d_t_2m.grib2.bz2
# Downloaded: icon-d2_germany_regular-lat-lon_single-level_2023082115_021_2d_t_2m.grib2.bz2
# Downloaded: icon-d2_germany_regular-lat-lon_single-level_2023082115_022_2d_t_2m.grib2.bz2
# Downloaded: icon-d2_germany_regular-lat-lon_single-level_2023082115_023_2d_t_2m.grib2.bz2
# Downloaded: icon-d2_germany_regular-lat-lon_single-level_2023082115_024_2d_t_2m.grib2.bz2
# Downloaded: icon-d2_germany_regular-lat-lon_single-level_2023082115_025_2d_t_2m.grib2.bz2
# Downloaded: icon-d2_germany_regular-lat-lon_single-level_2023082115_026_2d_t_2m.grib2.bz2
# Downloaded: icon-d2_germany_regular-lat-lon_single-level_2023082115_027_2d_t_2m.grib2.bz2
# Downloaded: icon-d2_germany_regular-lat-lon_single-level_2023082115_028_2d_t_2m.grib2.bz2
# Downloaded: icon-d2_germany_regular-lat-lon_single-level_2023082115_029_2d_t_2m.grib2.bz2
# Downloaded: icon-d2_germany_regular-lat-lon_single-level_2023082115_030_2d_t_2m.grib2.bz2
# Downloaded: icon-d2_germany_regular-lat-lon_single-level_2023082115_031_2d_t_2m.grib2.bz2
# Downloaded: icon-d2_germany_regular-lat-lon_single-level_2023082115_032_2d_t_2m.grib2.bz2
# Downloaded: icon-d2_germany_regular-lat-lon_single-level_2023082115_033_2d_t_2m.grib2.bz2
# Downloaded: icon-d2_germany_regular-lat-lon_single-level_2023082115_034_2d_t_2m.grib2.bz2
# Downloaded: icon-d2_germany_regular-lat-lon_single-level_2023082115_035_2d_t_2m.grib2.bz2
# Downloaded: icon-d2_germany_regular-lat-lon_single-level_2023082115_036_2d_t_2m.grib2.bz2
# Downloaded: icon-d2_germany_regular-lat-lon_single-level_2023082115_037_2d_t_2m.grib2.bz2
# Downloaded: icon-d2_germany_regular-lat-lon_single-level_2023082115_038_2d_t_2m.grib2.bz2
# Downloaded: icon-d2_germany_regular-lat-lon_single-level_2023082115_039_2d_t_2m.grib2.bz2
# Downloaded: icon-d2_germany_regular-lat-lon_single-level_2023082115_040_2d_t_2m.grib2.bz2
# Downloaded: icon-d2_germany_regular-lat-lon_single-level_2023082115_041_2d_t_2m.grib2.bz2
# Downloaded: icon-d2_germany_regular-lat-lon_single-level_2023082115_042_2d_t_2m.grib2.bz2
# Downloaded: icon-d2_germany_regular-lat-lon_single-level_2023082115_043_2d_t_2m.grib2.bz2
# Downloaded: icon-d2_germany_regular-lat-lon_single-level_2023082115_044_2d_t_2m.grib2.bz2
# Downloaded: icon-d2_germany_regular-lat-lon_single-level_2023082115_045_2d_t_2m.grib2.bz2
# Downloaded: icon-d2_germany_regular-lat-lon_single-level_2023082115_046_2d_t_2m.grib2.bz2
# Downloaded: icon-d2_germany_regular-lat-lon_single-level_2023082115_047_2d_t_2m.grib2.bz2
# Download complete.
