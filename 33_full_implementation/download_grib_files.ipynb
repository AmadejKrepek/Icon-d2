# %%
import requests
import os

# URL for the directory containing GRIB files
base_url = "https://opendata.dwd.de/weather/nwp/icon-d2/grib/03/t_2m/"

# Directory to save downloaded files
output_directory = "downloaded_grib_files"

# Create the output directory if it doesn't exist
os.makedirs(output_directory, exist_ok=True)
# Loop through the dynamic values from 000 to 047
for dynamic_value in range(48):
    filename = f"icon-d2_germany_regular-lat-lon_single-level_2023082203_{dynamic_value:03d}_2d_t_2m.grib2.bz2"
    url = f"{base_url}/{filename}"
    output_path = os.path.join(output_directory, filename)

    response = requests.get(url)
    with open(output_path, "wb") as f:
        f.write(response.content)

    print(f"Downloaded: {filename}")

print("Download complete.")
# Out:
# Downloaded: icon-d2_germany_regular-lat-lon_single-level_2023082203_000_2d_t_2m.grib2.bz2
# Downloaded: icon-d2_germany_regular-lat-lon_single-level_2023082203_001_2d_t_2m.grib2.bz2
# Downloaded: icon-d2_germany_regular-lat-lon_single-level_2023082203_002_2d_t_2m.grib2.bz2
# Downloaded: icon-d2_germany_regular-lat-lon_single-level_2023082203_003_2d_t_2m.grib2.bz2
# Downloaded: icon-d2_germany_regular-lat-lon_single-level_2023082203_004_2d_t_2m.grib2.bz2
# Downloaded: icon-d2_germany_regular-lat-lon_single-level_2023082203_005_2d_t_2m.grib2.bz2
# Downloaded: icon-d2_germany_regular-lat-lon_single-level_2023082203_006_2d_t_2m.grib2.bz2
# Downloaded: icon-d2_germany_regular-lat-lon_single-level_2023082203_007_2d_t_2m.grib2.bz2
# Downloaded: icon-d2_germany_regular-lat-lon_single-level_2023082203_008_2d_t_2m.grib2.bz2
# Downloaded: icon-d2_germany_regular-lat-lon_single-level_2023082203_009_2d_t_2m.grib2.bz2
# Downloaded: icon-d2_germany_regular-lat-lon_single-level_2023082203_010_2d_t_2m.grib2.bz2
# Downloaded: icon-d2_germany_regular-lat-lon_single-level_2023082203_011_2d_t_2m.grib2.bz2
# Downloaded: icon-d2_germany_regular-lat-lon_single-level_2023082203_012_2d_t_2m.grib2.bz2
# Downloaded: icon-d2_germany_regular-lat-lon_single-level_2023082203_013_2d_t_2m.grib2.bz2
# Downloaded: icon-d2_germany_regular-lat-lon_single-level_2023082203_014_2d_t_2m.grib2.bz2
# Downloaded: icon-d2_germany_regular-lat-lon_single-level_2023082203_015_2d_t_2m.grib2.bz2
# Downloaded: icon-d2_germany_regular-lat-lon_single-level_2023082203_016_2d_t_2m.grib2.bz2
# Downloaded: icon-d2_germany_regular-lat-lon_single-level_2023082203_017_2d_t_2m.grib2.bz2
# Downloaded: icon-d2_germany_regular-lat-lon_single-level_2023082203_018_2d_t_2m.grib2.bz2
# Downloaded: icon-d2_germany_regular-lat-lon_single-level_2023082203_019_2d_t_2m.grib2.bz2
# Downloaded: icon-d2_germany_regular-lat-lon_single-level_2023082203_020_2d_t_2m.grib2.bz2
# Downloaded: icon-d2_germany_regular-lat-lon_single-level_2023082203_021_2d_t_2m.grib2.bz2
# Downloaded: icon-d2_germany_regular-lat-lon_single-level_2023082203_022_2d_t_2m.grib2.bz2
# Downloaded: icon-d2_germany_regular-lat-lon_single-level_2023082203_023_2d_t_2m.grib2.bz2
# Downloaded: icon-d2_germany_regular-lat-lon_single-level_2023082203_024_2d_t_2m.grib2.bz2
# Downloaded: icon-d2_germany_regular-lat-lon_single-level_2023082203_025_2d_t_2m.grib2.bz2
# Downloaded: icon-d2_germany_regular-lat-lon_single-level_2023082203_026_2d_t_2m.grib2.bz2
# Downloaded: icon-d2_germany_regular-lat-lon_single-level_2023082203_027_2d_t_2m.grib2.bz2
# Downloaded: icon-d2_germany_regular-lat-lon_single-level_2023082203_028_2d_t_2m.grib2.bz2
# Downloaded: icon-d2_germany_regular-lat-lon_single-level_2023082203_029_2d_t_2m.grib2.bz2
# Downloaded: icon-d2_germany_regular-lat-lon_single-level_2023082203_030_2d_t_2m.grib2.bz2
# Downloaded: icon-d2_germany_regular-lat-lon_single-level_2023082203_031_2d_t_2m.grib2.bz2
# Downloaded: icon-d2_germany_regular-lat-lon_single-level_2023082203_032_2d_t_2m.grib2.bz2
# Downloaded: icon-d2_germany_regular-lat-lon_single-level_2023082203_033_2d_t_2m.grib2.bz2
# Downloaded: icon-d2_germany_regular-lat-lon_single-level_2023082203_034_2d_t_2m.grib2.bz2
# Downloaded: icon-d2_germany_regular-lat-lon_single-level_2023082203_035_2d_t_2m.grib2.bz2
# Downloaded: icon-d2_germany_regular-lat-lon_single-level_2023082203_036_2d_t_2m.grib2.bz2
# Downloaded: icon-d2_germany_regular-lat-lon_single-level_2023082203_037_2d_t_2m.grib2.bz2
# Downloaded: icon-d2_germany_regular-lat-lon_single-level_2023082203_038_2d_t_2m.grib2.bz2
# Downloaded: icon-d2_germany_regular-lat-lon_single-level_2023082203_039_2d_t_2m.grib2.bz2
# Downloaded: icon-d2_germany_regular-lat-lon_single-level_2023082203_040_2d_t_2m.grib2.bz2
# Downloaded: icon-d2_germany_regular-lat-lon_single-level_2023082203_041_2d_t_2m.grib2.bz2
# Downloaded: icon-d2_germany_regular-lat-lon_single-level_2023082203_042_2d_t_2m.grib2.bz2
# Downloaded: icon-d2_germany_regular-lat-lon_single-level_2023082203_043_2d_t_2m.grib2.bz2
# Downloaded: icon-d2_germany_regular-lat-lon_single-level_2023082203_044_2d_t_2m.grib2.bz2
# Downloaded: icon-d2_germany_regular-lat-lon_single-level_2023082203_045_2d_t_2m.grib2.bz2
# Downloaded: icon-d2_germany_regular-lat-lon_single-level_2023082203_046_2d_t_2m.grib2.bz2
# Downloaded: icon-d2_germany_regular-lat-lon_single-level_2023082203_047_2d_t_2m.grib2.bz2
# Download complete.
